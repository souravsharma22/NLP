# %%
import gensim

# %%
import re
from nltk.corpus import stopwords

# %%
import pandas as pd 
messages = pd.read_csv('SMSSpamCollection.txt',sep='\t',names= ['labels','statement'])

# %%
from nltk.stem import WordNetLemmatizer
lm = WordNetLemmatizer()

corpus=[]
for i in range(0,len(messages)):
    review = re.sub('[^a-zA-Z]',' ',messages['statement'][i])
    review = review.lower()
    review = review.split()
    review=[lm.lemmatize(word) for word in review]
    review=' '.join(review)
    corpus.append(review)

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
words=[]
for sent in corpus:
    sent_token = sent_tokenize(sent)
    for sentance in sent_token:
        words.append(simple_preprocess(sentance))

# %%
import gensim
model=gensim.models.Word2Vec(words)

# %%
model.wv.index_to_key
# Out:
# ['to',
#  'you',
#  'the',
#  'it',
#  'and',
#  'in',
#  'is',
#  'me',
#  'my',
#  'for',
#  'your',
#  'call',
#  'of',
#  'that',
#  'have',
#  'on',
#  'now',
#  'are',
#  'can',
#  'so',
#  'but',
#  'not',
#  'or',
#  'we',
#  'do',
#  'get',
#  'at',
#  'ur',
#  'will',
#  'if',
#  'be',
#  'with',
#  'no',
#  'just',
#  'this',
#  'gt',
#  'lt',
#  'go',
#  'how',
#  'up',
#  'when',
#  'ok',
#  'day',
#  'what',
#  'free',
#  'from',
#  'all',
#  'out',
#  'know',
#  'll',
#  'come',
#  'like',
#  'good',
#  'time',
#  'am',
#  'then',
#  'got',
#  'wa',
#  'there',
#  'he',
#  'love',
#  'text',
#  'only',
#  'want',
#  'send',
#  'one',
#  'need',
#  'txt',
#  'today',
#  'by',
#  'going',
#  'don',
#  'stop',
#  'home',
#  'she',
#  'about',
#  'lor',
#  'sorry',
#  'see',
#  'still',
#  'mobile',
#  'take',
#  'back',
#  'da',
#  'reply',
#  'dont',
#  'our',
#  'think',
#  'tell',
#  'week',
#  'hi',
#  'phone',
#  'they',
#  'new',
#  'please',
#  'later',
#  'pls',
#  'any',
#  'her',
#  'ha',
#  'co',
#  'did',
#  'been',
#  'msg',
#  'min',
#  'some',
#  'an',
#  'night',
#  'make',
#  'dear',
#  'who',
#  'here',
#  'message',
#  'say',
#  'well',
#  'where',
#  're',
#  'thing',
#  'much',
#  'oh',
#  'great',
#  'claim',
#  'hope',
#  'hey',
#  'him',
#  'number',
#  'give',
#  'more',
#  'too',
#  'happy',
#  'work',
#  'wat',
#  'friend',
#  'had',
#  'yes',
#  'way',
#  'www',
#  've',
#  'let',
#  'should',
#  'prize',
#  'won',
#  'right',
#  'tomorrow',
#  'already',
#  'tone',
#  'after',
#  'ask',
#  'win',
#  'said',
#  'life',
#  'amp',
#  'cash',
#  'doing',
#  'im',
#  'yeah',
#  'really',
#  'meet',
#  'babe',
#  'why',
#  'find',
#  'them',
#  'miss',
#  'morning',
#  'very',
#  'last',
#  'year',
#  'service',
#  'thanks',
#  'uk',
#  'care',
#  'com',
#  'would',
#  'anything',
#  'lol',
#  'nokia',
#  'also',
#  'every',
#  'feel',
#  'keep',
#  'sure',
#  'pick',
#  'urgent',
#  'over',
#  'sent',
#  'contact',
#  'something',
#  'buy',
#  'gud',
#  'again',
#  'cant',
#  'wait',
#  'before',
#  'place',
#  'box',
#  'first',
#  'his',
#  'even',
#  'someone',
#  'guy',
#  'help',
#  'went',
#  'wish',
#  'next',
#  'tonight',
#  'were',
#  'nice',
#  'soon',
#  'show',
#  'which',
#  'off',
#  'around',
#  'word',
#  'could',
#  'customer',
#  'money',
#  'sleep',
#  'chat',
#  'per',
#  'many',
#  'late',
#  'always',
#  'ya',
#  'gonna',
#  'sm',
#  'down',
#  'leave',
#  'wan',
#  'name',
#  'lot',
#  'end',
#  'other',
#  'dun',
#  'pm',
#  'told',
#  'st',
#  'person',
#  'waiting',
#  'hello',
#  'special',
#  'try',
#  'month',
#  'girl',
#  'hour',
#  'may',
#  'fine',
#  'best',
#  'haha',
#  'minute',
#  'heart',
#  'people',
#  'coming',
#  'done',
#  'guaranteed',
#  'yet',
#  'thk',
#  'same',
#  'th',
#  'getting',
#  'smile',
#  'ppm',
#  'use',
#  'thought',
#  'god',
#  'didn',
#  'offer',
#  'stuff',
#  'holiday',
#  'talk',
#  'start',
#  'class',
#  'man',
#  'cost',
#  'live',
#  'mean',
#  'bit',
#  'line',
#  'car',
#  'lunch',
#  'few',
#  'draw',
#  'finish',
#  'job',
#  'being',
#  'problem',
#  'never',
#  'yup',
#  'ill',
#  'better',
#  'plan',
#  'trying',
#  'house',
#  'thats',
#  'cool',
#  'hr',
#  'meeting',
#  'account',
#  'rate',
#  'mind',
#  'pobox',
#  'ready',
#  'having',
#  'dat',
#  'long',
#  'weekend',
#  'game',
#  'chance',
#  'world',
#  'real',
#  'half',
#  'enjoy',
#  'latest',
#  'wk',
#  'po',
#  'room',
#  'yo',
#  'sir',
#  'check',
#  'because',
#  'than',
#  'bt',
#  'guess',
#  'play',
#  'awarded',
#  'wanna',
#  'nothing',
#  'lar',
#  'receive',
#  'boy',
#  'voucher',
#  'eat',
#  'sweet',
#  'luv',
#  'look',
#  'camera',
#  'pic',
#  'another',
#  'liao',
#  'big',
#  'shit',
#  'dinner',
#  'into',
#  'ah',
#  'landline',
#  'birthday',
#  'xxx',
#  'jus',
#  'might',
#  'ever',
#  'quite',
#  'video',
#  'kiss',
#  'age',
#  'watching',
#  'wont',
#  'question',
#  'land',
#  'watch',
#  'dream',
#  'orange',
#  'early',
#  'thanx',
#  'worry',
#  'baby',
#  'called',
#  'speak',
#  'two',
#  'tv',
#  'aight',
#  'once',
#  'hear',
#  'fun',
#  'probably',
#  'nd',
#  'point',
#  'bed',
#  'pa',
#  'pay',
#  'doe',
#  'actually',
#  'network',
#  'princess',
#  'nite',
#  'apply',
#  'maybe',
#  'shall',
#  'bus',
#  'part',
#  'sat',
#  'left',
#  'forgot',
#  'den',
#  'bad',
#  'ringtone',
#  'remember',
#  'office',
#  'hurt',
#  'easy',
#  'reach',
#  'code',
#  'shopping',
#  'between',
#  'dunno',
#  'made',
#  'xx',
#  'dis',
#  'little',
#  'evening',
#  'didnt',
#  'award',
#  'put',
#  'true',
#  'leh',
#  'fuck',
#  'everything',
#  'wife',
#  'anyway',
#  'face',
#  'dad',
#  'looking',
#  'town',
#  'thank',
#  'afternoon',
#  'gift',
#  'school',
#  'enough',
#  'sound',
#  'those',
#  'mail',
#  'working',
#  'mate',
#  'selected',
#  'yr',
#  'movie',
#  'most',
#  'collect',
#  'pound',
#  'detail',
#  'without',
#  'asked',
#  'entry',
#  'while',
#  'missing',
#  'tmr',
#  'hav',
#  'join',
#  'price',
#  'sexy',
#  'okay',
#  'though',
#  'pain',
#  'wif',
#  'important',
#  'must',
#  'xmas',
#  'wanted',
#  'until',
#  'since',
#  'valid',
#  'came',
#  'update',
#  'mob',
#  'answer',
#  'wot',
#  'lesson',
#  'missed',
#  'wake',
#  'book',
#  'abt',
#  'run',
#  'collection',
#  'bring',
#  'able',
#  'til',
#  'wen',
#  'haven',
#  'decimal',
#  'de',
#  'test',
#  'charge',
#  'juz',
#  'plus',
#  'change',
#  'stay',
#  'date',
#  'plz',
#  'colour',
#  'away',
#  'double',
#  'weekly',
#  'havent',
#  'yesterday',
#  'saw',
#  'else',
#  'music',
#  'till',
#  'shop',
#  'dude',
#  'bored',
#  'attempt',
#  'alright',
#  'hair',
#  'lei',
#  'food',
#  'optout',
#  'trip',
#  'credit',
#  'friendship',
#  'making',
#  'drink',
#  'net',
#  'these',
#  'online',
#  'id',
#  'haf',
#  'yours',
#  'top',
#  'oso',
#  'coz',
#  'goin',
#  'tried',
#  'gr',
#  'family',
#  'address',
#  'delivery',
#  'sch',
#  'hot',
#  'player',
#  'club',
#  'either',
#  'smoke',
#  'ard',
#  'driving',
#  'feeling',
#  'national',
#  'yourself',
#  'nt',
#  'sad',
#  'order',
#  'lose',
#  'together',
#  'calling',
#  'full',
#  'wid',
#  'second',
#  'story',
#  'mom',
#  'busy',
#  'ring',
#  'beautiful',
#  'head',
#  'bonus',
#  'walk',
#  'http',
#  'brother',
#  'tot',
#  'both',
#  'si',
#  'sae',
#  'post',
#  'believe',
#  'smiling',
#  'huh',
#  'close',
#  'poly',
#  'old',
#  'eve',
#  'row',
#  'chikku',
#  'happen',
#  'noe',
#  'drive',
#  'await',
#  'set',
#  'info',
#  'hand',
#  'saying',
#  'mum',
#  'sleeping',
#  'leaving',
#  'awesome',
#  'mths',
#  'took',
#  'congrats',
#  'pub',
#  'hl',
#  'email',
#  'drop',
#  'parent',
#  'wil',
#  'rite',
#  'tomo',
#  'match',
#  'thinking',
#  'suite',
#  'started',
#  'news',
#  'simple',
#  'aft',
#  'finished',
#  'private',
#  'cause',
#  'doesn',
#  'okie',
#  'tho',
#  'unsubscribe',
#  'auction',
#  'available',
#  'tc',
#  'forget',
#  'content',
#  'everyone',
#  'company',
#  'anyone',
#  'sister',
#  'touch',
#  'break',
#  'caller',
#  'valentine',
#  'reason',
#  'mine',
#  'final',
#  'card',
#  'angry',
#  'neva',
#  'taking',
#  'gd',
#  'statement',
#  'open',
#  'dating',
#  'loving',
#  'whats',
#  'alone',
#  'found',
#  'treat',
#  'whatever',
#  'lucky',
#  'fancy',
#  'carlos',
#  'gal',
#  'choose',
#  'worth',
#  'opt',
#  'each',
#  'ticket',
#  'search',
#  'sun',
#  'knw',
#  'type',
#  'bank',
#  'expires',
#  'wonderful',
#  'frnd',
#  'hows',
#  'mobileupd',
#  'hit',
#  'winner',
#  'hard',
#  'boytoy',
#  'gone',
#  'saturday',
#  'gbp',
#  'welcome',
#  'fast',
#  'happened',
#  'quiz',
#  'anytime',
#  'kind',
#  'congratulation',
#  'bout',
#  'secret',
#  'far',
#  'identifier',
#  'decided',
#  'sub',
#  'ni',
#  'exam',
#  'uncle',
#  'ltd',
#  'party',
#  'smth',
#  'friday',
#  'college',
#  'visit',
#  'nyt',
#  'prob',
#  'song',
#  'darlin',
#  'mu',
#  'hold',
#  'read',
#  'light',
#  'operator',
#  'oredi',
#  'goodmorning',
#  'finally',
#  'mrng',
#  'tel',
#  'sea',
#  'wit',
#  'used',
#  'camcorder',
#  'wrong',
#  'least',
#  'wonder',
#  'fucking',
#  'drug',
#  'chennai',
#  'project',
#  'lovely',
#  'crazy',
#  'fri',
#  'term',
#  'nope',
#  'outside',
#  'pretty',
#  'fone',
#  'meant',
#  'frm',
#  'hmm',
#  'seeing',
#  'savamob',
#  'telling',
#  'case',
#  'fr',
#  'ten',
#  'whole',
#  'cum',
#  'cd',
#  'their',
#  'unlimited',
#  'blue',
#  'frnds',
#  'listen',
#  'snow',
#  'le',
#  'freemsg',
#  'support',
#  'wkly',
#  'wq',
#  'earlier',
#  'isn',
#  'course',
#  'hungry',
#  'jay',
#  'wasn',
#  'sunday',
#  'log',
#  'john',
#  'understand',
#  'enter',
#  'eh',
#  'single',
#  'cut',
#  'gas',
#  'un',
#  'father',
#  'valued',
#  'within',
#  'stupid',
#  'press',
#  'mr',
#  'hee',
#  'die',
#  'hmmm',
#  'yar',
#  'happiness',
#  'move',
#  'almost',
#  'knew',
#  'child',
#  'store',
#  'tired',
#  'bslvyl',
#  'mayb',
#  'sell',
#  'gn',
#  'balance',
#  'na',
#  'dnt',
#  'film',
#  'sex',
#  'paper',
#  'luck',
#  'joy',
#  'pas',
#  'moment',
#  'etc',
#  'march',
#  'side',
#  'area',
#  'sk',
#  'currently',
#  'couple',
#  'txts',
#  'computer',
#  'rock',
#  'invited',
#  'felt',
#  'as',
#  'ago',
#  'download',
#  'india',
#  'talking',
#  'mah',
#  'christmas',
#  'lost',
#  'park',
#  'motorola',
#  'load',
#  'reading',
#  'shower',
#  'hospital',
#  'bill',
#  'picking',
#  'askd',
#  'ipod',
#  'darren',
#  'eye',
#  'direct',
#  'return',
#  'heard',
#  'rental',
#  'photo',
#  'extra',
#  'confirm',
#  'semester',
#  'correct',
#  'via',
#  'red',
#  'doin',
#  'ac',
#  'information',
#  'supposed',
#  'reveal',
#  'wow',
#  'sort',
#  'laptop',
#  'ugh',
#  'charged',
#  'xy',
#  'bcoz',
#  'sending',
#  'ish',
#  'swing',
#  'seen',
#  'redeemed',
#  'difficult',
#  'ge',
#  'through',
#  'promise',
#  'met',
#  'max',
#  'lady',
#  'gym',
#  'complimentary',
#  'kid',
#  'gotta',
#  'comp',
#  'grin',
#  'surprise',
#  'figure',
#  'police',
#  'whenever',
#  'discount',
#  'slowly',
#  'ex',
#  'yep',
#  'muz',
#  'lovable',
#  'request',
#  'bath',
#  'hg',
#  'std',
#  'abiola',
#  'crave',
#  'usf',
#  'eg',
#  'loan',
#  'reward',
#  'safe',
#  'small',
#  'road',
#  'wine',
#  'comin',
#  'slow',
#  'weed',
#  'nobody',
#  'truth',
#  'link',
#  'wap',
#  'study',
#  'fantasy',
#  'fact',
#  'loved',
#  'orchard',
#  'cheer',
#  'asap',
#  'kate',
#  'somebody',
#  'page',
#  'noon',
#  'remove',
#  'rply',
#  'hmv',
#  'leaf',
#  'entered',
#  'txting',
#  'blood',
#  'rest',
#  'wana',
#  'idea',
#  'clean',
#  'dogging',
#  'door',
#  'asking',
#  'checking',
#  'train',
#  'own',
#  'lover',
#  'laugh',
#  'joke',
#  'save',
#  'rent',
#  'member',
#  'monday',
#  'pete',
#  'copy',
#  'empty',
#  'deal',
#  'nah',
#  'near',
#  'del',
#  'forever',
#  'mistake',
#  'energy',
#  'cup',
#  'normal',
#  'somewhere',
#  'men',
#  'england',
#  'la',
#  'situation',
#  'opinion',
#  'cheap',
#  'warm',
#  'hoping',
#  'water',
#  'across',
#  'woke',
#  'hw',
#  'usual',
#  'rakhesh',
#  'callertune',
#  'spend',
#  'med',
#  'em',
#  'cover',
#  'write',
#  'short',
#  'gave',
#  'bb',
#  'ringtones',
#  'tonite',
#  'bathe',
#  'different',
#  'voice',
#  'teach',
#  'ho',
#  'otherwise',
#  'king',
#  'merry',
#  'gap',
#  'poor',
#  'fantastic',
#  'booked',
#  'oops',
#  'wc',
#  'gettin',
#  'bag',
#  'admirer',
#  'getzed',
#  'ldn',
#  'kick',
#  'glad',
#  'immediately',
#  'street',
#  'summer',
#  'wishing',
#  'representative',
#  'cr',
#  'ntt',
#  'sony',
#  'rd',
#  'deep',
#  'worried',
#  'turn',
#  'catch',
#  'reached',
#  'pray',
#  ...]

# %%
model.corpus_count
# Out:
# 5569

# %%
model.epochs
# Out:
# 5

# %%
model.wv.similar_by_word('boy')
# Out:
# [('smile', 0.9993889927864075),
#  ('amp', 0.9993854761123657),
#  ('lol', 0.9993816018104553),
#  ('yet', 0.9993781447410583),
#  ('god', 0.9993379712104797),
#  ('never', 0.9993220567703247),
#  ('hello', 0.9993124604225159),
#  ('had', 0.9993014931678772),
#  ('ya', 0.9992964863777161),
#  ('all', 0.9992872476577759)]

# %%
model.wv['good'].shape
# Out:
# (100,)

# %%
words[0]
# Out:
# ['go',
#  'until',
#  'jurong',
#  'point',
#  'crazy',
#  'available',
#  'only',
#  'in',
#  'bugis',
#  'great',
#  'world',
#  'la',
#  'buffet',
#  'cine',
#  'there',
#  'got',
#  'amore',
#  'wat']

# %%
import numpy as np
def avgWord2Vec(doc):
    return np.mean([model.wv[word] for word in doc if word in model.wv.index_to_key],axis=0)

# %%
from tqdm import tqdm

# %%
x=[]
for i in tqdm(range(len(words))):
    x.append(avgWord2Vec(words[i]))
# Out:
#   0%|          | 0/5569 [00:00<?, ?it/s]c:\Users\hp\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\hp\anaconda3\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 5569/5569 [00:00<00:00, 7982.07it/s]

# %%
len(x)
# Out:
# 5569

# %%
x[0]
# Out:
# array([-0.16321237,  0.21417063,  0.12643245,  0.09505452,  0.08404776,
#        -0.49860814,  0.17221583,  0.4532148 , -0.2747535 , -0.13112248,
#        -0.14947207, -0.37144887, -0.03950592,  0.08879068,  0.21981236,
#        -0.142287  ,  0.10405745, -0.2969017 , -0.01517413, -0.5186649 ,
#         0.19726086,  0.10539834,  0.10060041, -0.20673834, -0.02093549,
#         0.00929802, -0.21083474, -0.18938588, -0.25476012,  0.05462109,
#         0.31658068,  0.01988596,  0.10934499, -0.182034  , -0.10030063,
#         0.4325413 ,  0.06764321, -0.13478336, -0.14269438, -0.45247847,
#         0.10100071, -0.26214924, -0.17249158, -0.0099444 ,  0.14811347,
#        -0.02204213, -0.13892555, -0.04018605,  0.22326517,  0.12834297,
#         0.19337536, -0.1976994 , -0.0470426 ,  0.05564539, -0.10607408,
#         0.07497789,  0.16839255,  0.02741965, -0.42328823,  0.14744005,
#         0.00257887,  0.15233634, -0.01751437, -0.0809374 , -0.30176002,
#         0.27641204,  0.06140862,  0.23874858, -0.32995564,  0.38956153,
#        -0.28147632,  0.17754456,  0.37424913, -0.10766988,  0.33833012,
#         0.0728077 ,  0.09335607, -0.08085237, -0.16265313,  0.10160445,
#        -0.20209578, -0.11054014, -0.24311647,  0.4560617 , -0.13471521,
#        -0.00347303,  0.05086486,  0.24485141,  0.33530563,  0.06107787,
#         0.35308295,  0.17685802,  0.00482459,  0.03699302,  0.42662302,
#         0.18606648,  0.16173294, -0.19330244,  0.16088589,  0.00148665],
#       dtype=float32)

# %%
x_new = np.array(x, dtype=object)

# %%
x_new[0]
# Out:
# array([-0.16321237,  0.21417063,  0.12643245,  0.09505452,  0.08404776,
#        -0.49860814,  0.17221583,  0.4532148 , -0.2747535 , -0.13112248,
#        -0.14947207, -0.37144887, -0.03950592,  0.08879068,  0.21981236,
#        -0.142287  ,  0.10405745, -0.2969017 , -0.01517413, -0.5186649 ,
#         0.19726086,  0.10539834,  0.10060041, -0.20673834, -0.02093549,
#         0.00929802, -0.21083474, -0.18938588, -0.25476012,  0.05462109,
#         0.31658068,  0.01988596,  0.10934499, -0.182034  , -0.10030063,
#         0.4325413 ,  0.06764321, -0.13478336, -0.14269438, -0.45247847,
#         0.10100071, -0.26214924, -0.17249158, -0.0099444 ,  0.14811347,
#        -0.02204213, -0.13892555, -0.04018605,  0.22326517,  0.12834297,
#         0.19337536, -0.1976994 , -0.0470426 ,  0.05564539, -0.10607408,
#         0.07497789,  0.16839255,  0.02741965, -0.42328823,  0.14744005,
#         0.00257887,  0.15233634, -0.01751437, -0.0809374 , -0.30176002,
#         0.27641204,  0.06140862,  0.23874858, -0.32995564,  0.38956153,
#        -0.28147632,  0.17754456,  0.37424913, -0.10766988,  0.33833012,
#         0.0728077 ,  0.09335607, -0.08085237, -0.16265313,  0.10160445,
#        -0.20209578, -0.11054014, -0.24311647,  0.4560617 , -0.13471521,
#        -0.00347303,  0.05086486,  0.24485141,  0.33530563,  0.06107787,
#         0.35308295,  0.17685802,  0.00482459,  0.03699302,  0.42662302,
#         0.18606648,  0.16173294, -0.19330244,  0.16088589,  0.00148665],
#       dtype=float32)

# %%
messages.shape
# Out:
# (5572, 2)

# %%
y = messages[list(map(lambda x: len(x)>0,corpus))]
y = pd.get_dummies(y['labels'])
y = y.iloc[:,0].values

# %%
df = pd.DataFrame()
for i in range(0,len(x)):
    df = df.append(pd.DataFrame(x[i].reshape(1,-1)),ignore_index=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18976\1193596894.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(x[i].reshape(1,-1)),ignore_index=True)

# %%
df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.163212  0.214171  0.126432  0.095055  0.084048 -0.498608  0.172216
# 1 -0.149390  0.188805  0.108723  0.084449  0.078447 -0.434603  0.138715
# 2 -0.169818  0.231578  0.137614  0.103649  0.073762 -0.547561  0.173884
# 3 -0.223648  0.293609  0.165459  0.134389  0.114182 -0.674940  0.227212
# 4 -0.197635  0.240968  0.148257  0.111018  0.106576 -0.572611  0.189393
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.453215 -0.274754 -0.131122  ...  0.353083  0.176858  0.004825  0.036993
# 1  0.399806 -0.240035 -0.109527  ...  0.311169  0.146260 -0.000383  0.025113
# 2  0.442303 -0.289896 -0.156296  ...  0.352130  0.187634 -0.003291  0.010131
# 3  0.623611 -0.376753 -0.171310  ...  0.479857  0.234015  0.003093  0.057675
# 4  0.531832 -0.321900 -0.153694  ...  0.413399  0.193820  0.006194  0.051162
#
#          94        95        96        97        98        99
# 0  0.426623  0.186066  0.161733 -0.193302  0.160886  0.001487
# 1  0.358257  0.155682  0.140001 -0.175525  0.145131 -0.006564
# 2  0.433130  0.172302  0.121646 -0.221939  0.183057  0.023306
# 3  0.566395  0.255639  0.234472 -0.263048  0.216157 -0.008482
# 4  0.480635  0.220159  0.191366 -0.236016  0.178128 -0.005386
#
# [5 rows x 100 columns]

# %%
x = df

# %%
df['output']=y

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.163212  0.214171  0.126432  0.095055  0.084048 -0.498608  0.172216
# 1 -0.149390  0.188805  0.108723  0.084449  0.078447 -0.434603  0.138715
# 2 -0.169818  0.231578  0.137614  0.103649  0.073762 -0.547561  0.173884
# 3 -0.223648  0.293609  0.165459  0.134389  0.114182 -0.674940  0.227212
# 4 -0.197635  0.240968  0.148257  0.111018  0.106576 -0.572611  0.189393
#
#           7         8         9  ...        91        92        93        94  \
# 0  0.453215 -0.274754 -0.131122  ...  0.176858  0.004825  0.036993  0.426623
# 1  0.399806 -0.240035 -0.109527  ...  0.146260 -0.000383  0.025113  0.358257
# 2  0.442303 -0.289896 -0.156296  ...  0.187634 -0.003291  0.010131  0.433130
# 3  0.623611 -0.376753 -0.171310  ...  0.234015  0.003093  0.057675  0.566395
# 4  0.531832 -0.321900 -0.153694  ...  0.193820  0.006194  0.051162  0.480635
#
#          95        96        97        98        99  output
# 0  0.186066  0.161733 -0.193302  0.160886  0.001487       1
# 1  0.155682  0.140001 -0.175525  0.145131 -0.006564       1
# 2  0.172302  0.121646 -0.221939  0.183057  0.023306       0
# 3  0.255639  0.234472 -0.263048  0.216157 -0.008482       1
# 4  0.220159  0.191366 -0.236016  0.178128 -0.005386       1
#
# [5 rows x 101 columns]

# %%
df.isnull().sum()
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 96        12
# 97        12
# 98        12
# 99        12
# output     0
# Length: 101, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# output    0
# Length: 101, dtype: int64

# %%
y = df['output']

# %%
x = df.drop(columns=['output'],axis=0)

# %%
x.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.163212  0.214171  0.126432  0.095055  0.084048 -0.498608  0.172216
# 1 -0.149390  0.188805  0.108723  0.084449  0.078447 -0.434603  0.138715
# 2 -0.169818  0.231578  0.137614  0.103649  0.073762 -0.547561  0.173884
# 3 -0.223648  0.293609  0.165459  0.134389  0.114182 -0.674940  0.227212
# 4 -0.197635  0.240968  0.148257  0.111018  0.106576 -0.572611  0.189393
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.453215 -0.274754 -0.131122  ...  0.353083  0.176858  0.004825  0.036993
# 1  0.399806 -0.240035 -0.109527  ...  0.311169  0.146260 -0.000383  0.025113
# 2  0.442303 -0.289896 -0.156296  ...  0.352130  0.187634 -0.003291  0.010131
# 3  0.623611 -0.376753 -0.171310  ...  0.479857  0.234015  0.003093  0.057675
# 4  0.531832 -0.321900 -0.153694  ...  0.413399  0.193820  0.006194  0.051162
#
#          94        95        96        97        98        99
# 0  0.426623  0.186066  0.161733 -0.193302  0.160886  0.001487
# 1  0.358257  0.155682  0.140001 -0.175525  0.145131 -0.006564
# 2  0.433130  0.172302  0.121646 -0.221939  0.183057  0.023306
# 3  0.566395  0.255639  0.234472 -0.263048  0.216157 -0.008482
# 4  0.480635  0.220159  0.191366 -0.236016  0.178128 -0.005386
#
# [5 rows x 100 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.20)

from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report
print(accuracy_score(y_true=y_test,y_pred=y_pred))
print(classification_report(y_true=y_test,y_pred=y_pred))
# Out:
# 0.9631294964028777
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87       165
#            1       0.97      0.99      0.98       947
#
#     accuracy                           0.96      1112
#    macro avg       0.94      0.91      0.92      1112
# weighted avg       0.96      0.96      0.96      1112
